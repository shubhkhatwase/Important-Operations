# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhkhatwase/Exploratory-data-analysis-/blob/main/M5_Prac_Load_Data_BY_ME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Load Data in various file format**
#
# ## **xlsx, csv, json, html, txt, pdf, jpg, png**

# %%
# Importing required libraries
from pandas import *
# import pandas as pd
import requests
import warnings
import time
warnings.filterwarnings("ignore")

# dir(pandas)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Load data in JPEG,PNG**

# %%
# Run this code in VS Code and keep the images in the same directory
from PIL import Image #The Python Imaging Library adds image processing capabilities to your Python interpreter.
# PIL.open(): load an image from a file
jpeg = Image.open("/content/drive/MyDrive/project/deep-learning-vs-machine-learning-t.jpg") 
png = Image.open("/content/drive/MyDrive/shubh/machine-learning.png")


#  format attribute identifies the source of an image. 
#  size attribute is a 2-tuple containing width and height (in pixels).
# The mode attribute defines the number and names of the bands in the image, and also the pixel type and depth. Common modes are “L” (luminance) for greyscale images, “RGB” for true color images, and “CMYK” for pre-press images.
print(jpeg.format, jpeg.size, jpeg.mode)
print(png.format, png.size, png.mode)
# Out:
# JPEG (1200, 630) RGB
# PNG (700, 394) P

# %%
jpeg
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x630 at 0x7F8D86D9A090>

# %%
png
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=700x394 at 0x7F8D84032450>

# %%
help(jpeg.size)
# Out:
# Help on tuple object:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
# ...

# %% [markdown]
# ##**Load data from PDF**

# %%
# Install tabula-py 
# tabula-py is a simple Python wrapper of tabula-java, which can read tables in a PDF.
# !pip install tabula-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 12.0 MB 5.1 MB/s
# ...

# %%
# read_pdf: Read tables in PDF.
from tabula import read_pdf
df = read_pdf('/content/drive/MyDrive/shubh/M5.pdf',pages=(1,2,3,4,5),multiple_tables=False,stream=True) #update your file path
# Out:
# Got stderr: Jul 10, 2022 3:22:02 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Jul 10, 2022 3:22:02 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Jul 10, 2022 3:22:03 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts
# Jul 10, 2022 3:22:03 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans-Bold' for 'TimesNewRomanPS-BoldMT'
# Jul 10, 2022 3:22:03 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
# Jul 10, 2022 3:22:04 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans-Bold' for 'TimesNewRomanPS-BoldMT'
# ...

# %%
help(read_pdf)
# Out:
# Help on function read_pdf in module tabula.io:
#
# read_pdf(input_path, output_format=None, encoding='utf-8', java_options=None, pandas_options=None, multiple_tables=True, user_agent=None, **kwargs)
#     Read tables in PDF.
#
#     Args:
#         input_path (str, path object or file-like object):
#             File like object of tareget PDF file.
#             It can be URL, which is downloaded by tabula-py automatically.
#         output_format (str, optional):
#             Output format for returned object (``dataframe`` or ``json``)
#         encoding (str, optional):
#             Encoding type for pandas. Default: ``utf-8``
#         java_options (list, optional):
#             Set java options.
#
#             Example:
#                 ``["-Xmx256m"]``
#         pandas_options (dict, optional):
#             Set pandas options.
#
#             Example:
#                 ``{'header': None}``
#
#             Note:
# ...

# %%
for i in df:
  print(i)
len(df)
# Out:
#    Unnamed: 0 Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     PARTNER    AIRLINE          NaN        NaN        NaN    ADVANCE
# 1        TYPE    LOYALTY  CABIN_CLASS    OS_TYPE     GENDER   PURCHASE
# 2         OTA  3 - Elite      Economy     Others       Male   4-7 Days
# 3         OTA  3 - Elite      Economy     Others       Male   4-7 Days
# 4         NaN        NaN          NaN        NaN        NaN    7 - 91+
# 5         OTA  3 - Elite      Economy        Mac     Female        NaN
# 6         NaN        NaN          NaN        NaN        NaN       Days
# 7         NaN        NaN          NaN        NaN        NaN    7 - 91+
# 8         OTA  3 - Elite      Economy        Mac     Female        NaN
# 9         NaN        NaN          NaN        NaN        NaN       Days
# 10        NaN        NaN          NaN        NaN        NaN    7 - 91+
# 11        OTA  3 - Elite      Economy        Mac       Male        NaN
# ...

# %%
import pandas as pd
data=pd.DataFrame(df[0])
data
# Out:
#    Unnamed: 0 Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     PARTNER    AIRLINE          NaN        NaN        NaN    ADVANCE
# 1        TYPE    LOYALTY  CABIN_CLASS    OS_TYPE     GENDER   PURCHASE
# 2         OTA  3 - Elite      Economy     Others       Male   4-7 Days
# 3         OTA  3 - Elite      Economy     Others       Male   4-7 Days
# 4         NaN        NaN          NaN        NaN        NaN    7 - 91+
# 5         OTA  3 - Elite      Economy        Mac     Female        NaN
# 6         NaN        NaN          NaN        NaN        NaN       Days
# 7         NaN        NaN          NaN        NaN        NaN    7 - 91+
# 8         OTA  3 - Elite      Economy        Mac     Female        NaN
# 9         NaN        NaN          NaN        NaN        NaN       Days
# 10        NaN        NaN          NaN        NaN        NaN    7 - 91+
# 11        OTA  3 - Elite      Economy        Mac       Male        NaN
# ...

# %%
'''
Assignment: Arrange the data in DataFrames
'''
# Out:
# '\nAssignment: Arrange the data in DataFrames\n'

# %% [markdown]
# ## **Load file from Txt**

# %%
txt=open("/content/drive/MyDrive/Business Requirements Analysis.txt") #update your file path
for i in txt.readlines(): #returns a list containing each line in the file as a list item:
  print(i.rstrip())
# Out:
# Business Requirements Analysis
#
# Chapter 1
# Various types of requirements in teams
# and organizations.
# 1.1 Business Requirement Analysis
# A business requirements analysis is all about identifying, analyzing, and documenting the key
# requirements related to a business problem that needs to be solved or an organizational objective that needs
# to be met.
#
# A requirement in the context of Business Analysis is simply a statement provided by a stakeholder
# about what they believe they need to solve a particular business problem or respond to a specific business
# need. Once this requirement has been raised by the stakeholder it is the business analyst’s role to further
# define, analyze, validate and prioritize the requirement statement as it is now included within the business
# analysis context of requirements management. In real life, the stakeholder will typically state their business
# ...

# %% [markdown]
# ## **Load data from opensource Websites.**

# %%
import pandas as pd
read_html=pd.read_html('https://en.wikipedia.org/wiki/Madhya_Pradesh') #Read HTML tables into a list of DataFrame objects.
type(read_html)
# Out:
# list

# %% [markdown]
# ##**Load file form JSON**

# %%
import json #Simple JSON decoder.
import requests

# %%
# Requests: an HTTP library, written in Python, 
# requests.get(): Sends a GET request.
# .status_code(): returns a number that indicates the status (200 is OK, 404 is Not Found).
response = requests.get("https://api.data.gov.in/resource/12ac3d94-71e7-43d5-a4bf-63e6518e7440?api-key=579b464db66ec23bdd0000019bd301ff1ca540ee4a8e16ac7c729e62&format=json&filters=1000")
print(response.status_code)
# Out:
# 200

# %%
# Loading Data
data_json = response.json()
print(type(data_json))
data_json
# Out:
# <class 'dict'>
# {'active': '1',
#  'catalog_uuid': '386149ed-781e-46a6-acd2-df9337e92097',
#  'count': 10,
#  'created': '1649398161944',
#  'created_date': '2022-04-08T11:39:42Z',
#  'desc': 'Petroleum Product of Customs Tariff and Central Excise (as on 01.04.2021)',
#  'field': [{'id': 'category', 'name': 'category', 'type': 'keyword'},
#   {'id': 'particulars', 'name': 'particulars', 'type': 'keyword'},
#   {'id': 'customs_basic_customs_duty',
#    'name': 'customs___basic_customs_duty',
#    'type': 'keyword'},
#   {'id': 'customs_cvd_in_lieu_of_igst_',
#    'name': 'customs___cvd_in_lieu_of_igst_',
#    'type': 'keyword'},
#   {'id': 'gst', 'name': 'gst', 'type': 'keyword'}],
#  'index_name': '12ac3d94-71e7-43d5-a4bf-63e6518e7440',
#  'limit': '10',
#  'message': 'Resource lists',
#  'offset': '0',
#  'org': ['Ministry of Petroleum and Natural Gas'],
#  'org_type': 'Central',
#  'records': [{'category': 'Petroleum Products on which GST is levied',
# ...

# %%
records =data_json['records']

# %%
import pandas as pd
# Creating DataFrame
df = pd.DataFrame(records)
df.head()
# Out:
#                                     category           particulars  \
# 0  Petroleum Products on which GST is levied        LPG - Domestic
# 1  Petroleum Products on which GST is levied  LPG - Non - Domestic
# 2  Petroleum Products on which GST is levied        Kerosene - PDS
# 3  Petroleum Products on which GST is levied    Kerosene - Non PDS
# 4  Petroleum Products on which GST is levied  Naphtha - Fertilizer
#
#   customs_basic_customs_duty customs_cvd_in_lieu_of_igst_     gst
# 0                        Nil                        5.00%   5.00%
# 1                      5.00%                       18.00%  18.00%
# 2                        Nil                        5.00%   5.00%
# 3                      5.00%                       18.00%  18.00%
# 4                        Nil                       18.00%  18.00%

# %%
print(category,len(category))
print(particulars,len(particulars))
print(customs_basic_customs_duty,len(customs_basic_customs_duty))
print(customs_cvd_in_lieu_of_igst_,len(customs_cvd_in_lieu_of_igst_))
print(gst,len(gst))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-e3ebe7d10a8c> in <module>()
#       1
# ----> 2 print(category,len(category))
#       3 print(particulars,len(particulars))
#       4 print(customs_basic_customs_duty,len(customs_basic_customs_duty))
#       5 print(customs_cvd_in_lieu_of_igst_,len(customs_cvd_in_lieu_of_igst_))
#
# NameError: name 'category' is not defined

# %% [markdown]
# ## **Load from xlsx & CSV**

# %%
import pandas as pd
readcsv = pd.read_csv('/content/drive/MyDrive/job_skills1.csv') # Read csv file

readcsv.head() # Read first 5 rows of DataFrame
# Out:
#   Company                                              Title  \
# 0  Google                       Google Cloud Program Manager
# 1  Google  Supplier Development Engineer (SDE), Cable/Con...
# 2  Google  Data Analyst, Product and Tools Operations, Go...
# 3  Google            Developer Advocate, Partner Engineering
# 4  Google     Program Manager, Audio Visual (AV) Deployments
#
#                        Category                          Location  \
# 0            Program Management                         Singapore
# 1  Manufacturing & Supply Chain                   Shanghai, China
# 2           Technical Solutions       New York, NY, United States
# 3           Developer Relations  Mountain View, CA, United States
# 4            Program Management      Sunnyvale, CA, United States
#
#                                     Responsibilities  \
# 0  Shape, shepherd, ship, and show technical prog...
# 1  Drive cross-functional activities in the suppl...
# ...

# %%
readexcel=pd.read_excel('/content/drive/MyDrive/shubh/Sample - Superstore.xlsx') # Read xlxs file

readexcel.head() # Read first 5 rows of DataFrame
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     1.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...
